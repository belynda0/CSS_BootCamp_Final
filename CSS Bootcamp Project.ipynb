# %% [markdown]
# main question :Do blue states have stricter crime policies than red states?
# To measure this, we are examining gubernatorial races that have flipped results to see the impact on prison populations over 5 year period. Is there a noticeable difference in population trends between Democratic and Republican states?
#
# The comparison between crime policies in blue states (typically Democratic) and red states (typically Republican) is complex and nuanced. Generally, blue states tend to implement more progressive policies, such as focusing on rehabilitation, reducing incarceration rates, and implementing stricter gun control laws. Red states, on the other hand, often emphasize tougher sentencing, increased police funding, and more lenient gun laws.
#
# However, the effectiveness and impact of these policies can vary widely. For instance, some studies suggest that red states have higher overall violent crime rates, while blue states may have higher crime rates in urban areas. Additionally, the differences in crime rates can often be attributed to various social, economic, and demographic factors rather than the policies themselves.
#
# The study has several **limitations** that must be acknowledged. Firstly, the analysis did not account for prisoners who died during the study period. Secondly, it overlooked prisoners who were transferred to facilities in other states. Additionally, individuals on parole were not considered in the evaluation. Lastly, the study did not fully address the impact of legislative changes and the time required for these laws to influence case outcomes. These factors collectively suggest that the findings may not fully capture the complexities of the prison system and its associated legal processes.

# %%
## Loading Libraries and Modules

# scikit-learn: barebones, but fast and reliable
from sklearn.linear_model import LogisticRegression 
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn.tree import DecisionTreeClassifier

# statsmodels: pretty and good to use, great for interpretable ML
from statsmodels.formula.api import ols
from statsmodels.formula.api import logit
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Data processing
import pandas as pd
import numpy as np

# Plotting things:
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# load the data sets
# https://www.prisonpolicy.org/data/prison_pops_2019_2023_sources.html
# https://en.wikipedia.org/wiki/2022_United_States_gubernatorial_elections#cite_note-11

# %%
ele_22 = pd.read_csv('2022_US_Gubernatorial_Elections.csv')
ppop = pd.read_csv('Prison_Data_2019-2023.csv')

# %% [markdown]
# join on the state then look for pop and result

# %%
ele_22.head()

# %%
ppop.head()

# %%
# Performing an inner join on the 'ID' column
r22 = pd.merge(ele_22, ppop, on='State', how='inner')

# Display the result
print(r22)
# Out:
#              State PVI[3]                   Incumbent[4] Last\nrace  \
# 0          Alabama   R+15                       Kay Ivey    59.5% R
# 1           Alaska    R+8                  Mike Dunleavy    51.4% R
# 2          Arizona    R+2      Doug Ducey (term-limited)    56.0% R
# 3         Arkansas   R+16  Asa Hutchinson (term-limited)    65.3% R
# 4       California   D+13                   Gavin Newsom    61.9% D
# 5         Colorado    D+4                    Jared Polis    53.4% D
# 6      Connecticut    D+7                     Ned Lamont    49.4% D
# 7          Florida    R+3                   Ron DeSantis    49.6% R
# 8          Georgia    R+3                     Brian Kemp    50.2% R
# 9           Hawaii   D+14       David Ige (term-limited)    62.7% D
# 10           Idaho   R+18                    Brad Little    59.8% R
# 11        Illinois    D+7                 J. B. Pritzker    54.5% D
# 12            Iowa    R+6                   Kim Reynolds    50.3% R
# 13          Kansas   R+10                    Laura Kelly    48.0% D
# 14           Maine    D+2                    Janet Mills    50.9% D
# 15        Maryland   D+14     Larry Hogan (term-limited)    55.4% R
# 16   Massachusetts   D+15       Charlie Baker (retiring)    66.6% R
# 17        Michigan    R+1               Gretchen Whitmer    53.3% D
# 18       Minnesota    D+1                       Tim Walz    53.8% D
# 19        Nebraska   R+13   Pete Ricketts (term-limited)    59.0% R
# 20          Nevada    R+1                  Steve Sisolak    49.4% D
# 21   New Hampshire    D+1                   Chris Sununu    65.1% R
# 22      New Mexico    D+3         Michelle Lujan Grisham    57.2% D
# 23        New York   D+10                   Kathy Hochul    59.6% D
# 24            Ohio    R+6                    Mike DeWine    50.4% R
# 25        Oklahoma   R+20                    Kevin Stitt    54.3% R
# 26          Oregon    D+6      Kate Brown (term-limited)    50.1% D
# 27    Pennsylvania    R+2        Tom Wolf (term-limited)    57.8% D
# 28    Rhode Island    D+8                      Dan McKee    52.6% D
# 29  South Carolina    R+8                 Henry McMaster    54.0% R
# 30    South Dakota   R+16                    Kristi Noem    51.0% R
# 31       Tennessee   R+14                       Bill Lee    59.6% R
# 32           Texas    R+5                    Greg Abbott    55.8% R
# 33         Vermont   D+16                     Phil Scott    68.5% R
# 34       Wisconsin    R+2                     Tony Evers    49.5% D
# 35         Wyoming   R+25                    Mark Gordon    67.1% R
#
#    Cook\nOct 28,\n2022[5] IE\nNov 3,\n2022[6] Sabato\nNov 7,\n2022[7]  \
# 0                 Solid R             Solid R                  Safe R
# 1                Likely R            Likely R                Likely R
# 2                  Tossup              Tossup                  Lean R
# 3                 Solid R             Solid R                  Safe R
# 4                 Solid D             Solid D                  Safe D
# 5                 Solid D             Solid D                  Safe D
# 6                 Solid D             Solid D                Likely D
# 7                Likely R            Likely R                  Safe R
# 8                  Lean R              Lean R                Likely R
# 9                 Solid D             Solid D                  Safe D
# 10                Solid R             Solid R                  Safe R
# 11                Solid D             Solid D                  Safe D
# 12                Solid R             Solid R                  Safe R
# 13                 Tossup              Tossup           Lean R (flip)
# 14                 Lean D              Lean D                  Lean D
# 15         Solid D (flip)     Likely D (flip)           Safe D (flip)
# 16         Solid D (flip)     Likely D (flip)           Safe D (flip)
# 17                 Lean D              Tilt D                  Lean D
# 18               Likely D              Lean D                Likely D
# 19                Solid R             Solid R                  Safe R
# 20                 Tossup              Tossup           Lean R (flip)
# 21                Solid R             Solid R                  Safe R
# 22                 Lean D              Tilt D                  Lean D
# 23               Likely D            Likely D                Likely D
# 24                Solid R             Solid R                  Safe R
# 25               Likely R            Likely R                Likely R
# 26                 Tossup              Tossup                  Lean D
# 27               Likely D              Lean D                Likely D
# 28                Solid D             Solid D                Likely D
# 29                Solid R             Solid R                  Safe R
# 30                Solid R             Solid R                  Safe R
# 31                Solid R             Solid R                  Safe R
# 32               Likely R             Solid R                Likely R
# 33                Solid R             Solid R                  Safe R
# 34                 Tossup              Tossup           Lean R (flip)
# 35                Solid R             Solid R                  Safe R
#
#    Politico\nNov 3,\n2022[8] RCP\nNov 2,\n2022[9] Fox\nNov 1,\n2022[10]  ...  \
# 0                    Solid R               Safe R               Solid R  ...
# 1                   Likely R             Likely R              Likely R  ...
# 2                     Tossup               Tossup                Tossup  ...
# 3                    Solid R               Safe R               Solid R  ...
# 4                    Solid D               Safe D               Solid D  ...
# 5                   Likely D             Likely D              Likely D  ...
# 6                     Lean D               Lean D              Likely D  ...
# 7                   Likely R               Lean R              Likely R  ...
# 8                     Lean R               Lean R                Lean R  ...
# 9                    Solid D               Safe D               Solid D  ...
# 10                   Solid R               Safe R               Solid R  ...
# 11                  Likely D               Lean D               Solid D  ...
# 12                   Solid R             Likely R               Solid R  ...
# 13                    Tossup               Tossup                Tossup  ...
# 14                    Lean D               Tossup                Lean D  ...
# 15            Solid D (flip)        Safe D (flip)        Solid D (flip)  ...
# 16            Solid D (flip)        Safe D (flip)        Solid D (flip)  ...
# 17                    Lean D               Tossup                Lean D  ...
# 18                    Lean D               Tossup                Lean D  ...
# 19                   Solid R               Safe R               Solid R  ...
# 20                    Tossup               Tossup                Tossup  ...
# 21                   Solid R               Safe R              Likely R  ...
# 22                    Lean D               Tossup                Tossup  ...
# 23                  Likely D               Tossup                Lean D  ...
# 24                  Likely R               Safe R              Likely R  ...
# 25                  Likely R               Tossup                Lean R  ...
# 26                    Tossup               Tossup                Tossup  ...
# 27                  Likely D               Lean D              Likely D  ...
# 28                  Likely D             Likely D              Likely D  ...
# 29                   Solid R               Safe R               Solid R  ...
# 30                  Likely R             Likely R               Solid R  ...
# 31                   Solid R               Safe R               Solid R  ...
# 32                  Likely R               Lean R              Likely R  ...
# 33                   Solid R               Safe R               Solid R  ...
# 34                    Tossup               Tossup                Tossup  ...
# 35                   Solid R               Safe R               Solid R  ...
#
#    ED\nNov 7,\n2022[12]                    Result     2019     2020     2021  \
# 0                Safe R             Ivey\n66.9% R   28,304   25,328   25,032
# 1              Likely R         Dunleavy\n50.3% R    4,475    4,578    4,639
# 2                Lean R     Hobbs\n50.3% D (flip)   42,441   37,794   33,914
# 3                Safe R          Sanders\n63.0% R   17,759   16,094   17,022
# 4                Safe D           Newsom\n59.2% D  122,687  100,396  101,441
# 5                Safe D            Polis\n58.5% D   19,785   16,259   15,865
# 6                Safe D           Lamont\n56.0% D   12,823    9,559    9,889
# 7                Safe R         DeSantis\n59.4% R   96,009   81,027   80,417
# 8              Likely R             Kemp\n53.4% R   54,816   47,141   47,010
# 9                Safe D            Green\n63.2% D    5,279    4,171    4,102
# 10               Safe R           Little\n60.5% R    9,437    8,356    8,907
# 11               Safe D         Pritzker\n54.9% D   38,259   29,729   28,980
# 12               Safe R         Reynolds\n58.0% R    9,282    8,307    8,562
# 13               Lean D            Kelly\n49.5% D   10,177    8,779    8,521
# 14               Lean D            Mills\n55.7% D    2,185    1,714    1,577
# 15        Safe D (flip)     Moore\n64.5% D (flip)   18,595   15,623   15,134
# 16        Safe D (flip)    Healey\n63.8% D (flip)    8,205    6,762    6,148
# 17               Lean D          Whitmer\n54.5% D   38,053   33,617   32,186
# 18             Likely D             Walz\n52.3% D    9,982    8,148    8,003
# 19               Safe R           Pillen\n59.7% R    5,682    5,306    5,600
# 20        Lean R (flip)  Lombardo\n48.8% R (flip)   12,840   11,249   10,202
# 21               Safe R           Sununu\n57.1% R    2,691    2,352    2,127
# 22               Lean D          Grisham\n52.0% D    6,723    5,500    5,154
# 23               Safe D           Hochul\n53.2% D   43,500   34,128   30,338
# 24               Safe R           DeWine\n62.4% R   50,338   45,036   45,029
# 25               Safe R            Stitt\n55.4% R   25,033   22,462   22,391
# 26               Lean D            Kotek\n47.0% D   14,961   12,753   13,198
# 27             Likely D          Shapiro\n56.5% D   45,702   39,357   37,194
# 28             Likely D            McKee\n58.1% D    2,740    2,227    2,238
# 29               Safe R         McMaster\n58.1% R   18,608   16,157   15,759
# 30               Safe R             Noem\n62.0% R    3,801    3,250    3,353
# 31               Safe R              Lee\n64.9% R   26,349   22,685   21,995
# 32             Likely R           Abbott\n54.8% R  158,429  135,906  133,772
# 33               Safe R            Scott\n70.9% R    1,608    1,284    1,287
# 34        Lean R (flip)            Evers\n51.2% D   23,956   20,298   20,202
# 35               Safe R           Gordon\n74.1% R    2,479    2,087    2,123
#
#        2022                                               2023  \
# 0    26,421                                             27,001
# 1     4,778                                              4,480
# 2    33,865                                             34,502
# 3    17,625                                             18,375
# 4    97,608                                             96,225
# 5    17,168                                             17,246
# 6    10,506                                             10,445
# 7    84,678                                             85,928
# 8    48,439                                             50,616
# 9     4,149                                              3,967
# 10    9,110                                              9,332
# 11   29,634                                             29,930
# 12    8,473                                              8,404
# 13    8,709                                              9,005
# 14    1,675                                              1,749
# 15   15,637                                       None located
# 16    6,001                                              6,144
# 17   32,374                                             33,461
# 18    8,636                                              8,274
# 19    5,649                                              5,803
# 20   10,304                                             10,535
# 21    2,086                                              2,100
# 22    4,970                                       None located
# 23   31,148                                             32,613
# 24   45,313                                             44,531
# 25   22,941                                       None located
# 26   12,518                                             12,143
# 27   37,910                                             38,934
# 28    2,393                                              2,350
# 29   16,318                                             16,539
# 30    3,444                                              3,727
# 31   23,735                                             25,011
# 32  139,631  No counts located that are compatible with BJS...
# 33    1,360                                              1,342
# 34   20,873                                             21,923
# 35    2,154                                              2,242
#
#                      2023 Population source and notes  \
# 0      ADOC Monthly Statistical Report for Sept. 2023
# 1   Summary Statistics for Nov. 2023 showing popul...
# 2             Dec. 14, 2023 Count Sheet (Grand total)
# 3   DOC Board Report for Sept. 2023 (jurisdictiona...
# 4   Monthly TPOP1 Report for Nov. 2023 (Total In-C...
# 5   “Inmate Total” from “General Statistics” dashb...
# 6   CT DOC Monthly Statistics Dec. 1, 2023 (data a...
# 7   FDC Monthly Statistical Report Nov. 2023 (data...
# 8   GA DOC Monthly Statistical Report, “Profile of...
# 9   HI DPS Corrections Division Weekly Population ...
# 10  ID DOC Incarcerated Population Report for Fisc...
# 11  IL DOC Prison Population Data Set for June 30,...
# 12  IA DOC Daily Statistics as of Dec. 15 2023 sho...
# 13  KS DOC Current populaton totals as of Dec. 13,...
# 14  ME DOC Nov. 2023 Monthly Adult Data Reporting ...
# 15                                                NaN
# 16  MA DOC Weekly Inmate Count as of Dec. 4, 2023 ...
# 17  MI DOC Nov. 2023 Prison Population Projection ...
# 18  MN DOC Adult Prison Population Summary for Jul...
# 19  NDCS Quarterly Population Summary showing Aver...
# 20  NV DOC Monthly Statistical Abstracts Factsheet...
# 21  NH Bar Association article, “NHBA Prison Serie...
# 22                                                NaN
# 23  NY DOCCS Incarcerated Profile Report - Dec. 20...
# 24  ODRC Monthly Population Count by Institution, ...
# 25                                                NaN
# 26    OR DOC Prison Population Trends as of Nov. 2023
# 27  PA DOC Monthly Population Report showing total...
# 28  RI DOC statistics as cited in the Providence J...
# 29  SC DOC “Average Daily Inmate Population - Fisc...
# 30  SD DOC Adult Corrections Population for Nov. 3...
# 31  TN DOC “Incarcerated Felon Populations” (Oct. ...
# 32                                                NaN
# 33  VT DOC “Jail Population” as of Dec. 15, 2023 (...
# 34  WI DOC Weekly Population Report showing “total...
# 35  WY DOC Quarterly Population Demographics Repor...
#
#                                            Source URL Unnamed: 8
# 0   https://doc.alabama.gov/docs/MonthlyRpts/Septe...        NaN
# 1   https://doc.alaska.gov/administrative-services...        NaN
# 2   https://corrections.az.gov/sites/default/files...        NaN
# 3   https://doc.arkansas.gov/wp-content/uploads/Di...        NaN
# 4   https://www.cdcr.ca.gov/research/wp-content/up...        NaN
# 5   https://cdoc.colorado.gov/about/data-and-repor...        NaN
# 6   https://portal.ct.gov/DOC/Report/Monthly-Stati...        NaN
# 7   https://fdc.myflorida.com/pub/statistics/MS112...        NaN
# 8   https://gdc.georgia.gov/document/monthly-stati...        NaN
# 9   https://dps.hawaii.gov/wp-content/uploads/2023...        NaN
# 10  https://www.idoc.idaho.gov/content/document/fy...        NaN
# 11  https://idoc.illinois.gov/content/dam/soi/en/w...        NaN
# 12        https://doc-search.iowa.gov/dailystatistics        NaN
# 13   https://www.doc.ks.gov/current_population_totals        NaN
# 14  https://www.maine.gov/corrections/sites/maine....        NaN
# 15                                                NaN        NaN
# 16  https://www.mass.gov/doc/weekly-inmate-count-1...        NaN
# 17  https://www.michigan.gov/corrections/-/media/P...        NaN
# 18  https://mn.gov/doc/assets/Adult Prison Populat...        NaN
# 19  https://corrections.nebraska.gov/sites/default...        NaN
# 20  https://doc.nv.gov/uploadedFiles/docnvgov/cont...        NaN
# 21  https://www.nhbar.org/nhba-prison-series-maint...        NaN
# 22                                                NaN        NaN
# 23  https://doccs.ny.gov/incarcerated-profile-repo...        NaN
# 24  https://drc.ohio.gov/wps/wcm/connect/gov/62283...        NaN
# 25                                                NaN        NaN
# 26  https://www.oregon.gov/doc/Documents/prison_po...        NaN
# 27  https://www.cor.pa.gov/About Us/Statistics/Doc...        NaN
# 28  https://www.providencejournal.com/story/news/s...        NaN
# 29  https://www.doc.sc.gov/sites/doc/files/Documen...        NaN
# 30  https://doc.sd.gov/documents/AdultPopulationNo...        NaN
# 31  https://www.tn.gov/content/dam/tn/correction/d...        NaN
# 32                                                NaN        NaN
# 33  https://doc.vermont.gov/sites/correct/files/do...        NaN
# 34  https://doc.wi.gov/DataResearch/WeeklyPopulati...        NaN
# 35  https://drive.google.com/file/d/1FoYznPX-3dJml...        NaN
#
# [36 rows x 21 columns]

# %%
r22.head()

# %% [markdown]
# looking at this data we will subset/drop many of the states we are looking at states that were toss ups from the RCP (right wing media). looking at right wing media will favor states that have a chance to turn red that historical are consider blue state

# %%
r22.info()

# %%
df = r22[r22.apply(lambda r: r.str.contains(r'\(flip\)').any(), axis=1)]
df.head()
# Out:
#             State PVI[3]                Incumbent[4] Last\nrace  \
# 2         Arizona    R+2   Doug Ducey (term-limited)    56.0% R
# 13         Kansas   R+10                 Laura Kelly    48.0% D
# 15       Maryland   D+14  Larry Hogan (term-limited)    55.4% R
# 16  Massachusetts   D+15    Charlie Baker (retiring)    66.6% R
# 20         Nevada    R+1               Steve Sisolak    49.4% D
#
#    Cook\nOct 28,\n2022[5] IE\nNov 3,\n2022[6] Sabato\nNov 7,\n2022[7]  \
# 2                  Tossup              Tossup                  Lean R
# 13                 Tossup              Tossup           Lean R (flip)
# 15         Solid D (flip)     Likely D (flip)           Safe D (flip)
# 16         Solid D (flip)     Likely D (flip)           Safe D (flip)
# 20                 Tossup              Tossup           Lean R (flip)
#
#    Politico\nNov 3,\n2022[8] RCP\nNov 2,\n2022[9] Fox\nNov 1,\n2022[10]  ...  \
# 2                     Tossup               Tossup                Tossup  ...
# 13                    Tossup               Tossup                Tossup  ...
# 15            Solid D (flip)        Safe D (flip)        Solid D (flip)  ...
# 16            Solid D (flip)        Safe D (flip)        Solid D (flip)  ...
# 20                    Tossup               Tossup                Tossup  ...
#
#    ED\nNov 7,\n2022[12]                    Result    2019    2020    2021  \
# 2                Lean R     Hobbs\n50.3% D (flip)  42,441  37,794  33,914
# 13               Lean D            Kelly\n49.5% D  10,177   8,779   8,521
# 15        Safe D (flip)     Moore\n64.5% D (flip)  18,595  15,623  15,134
# 16        Safe D (flip)    Healey\n63.8% D (flip)   8,205   6,762   6,148
# 20        Lean R (flip)  Lombardo\n48.8% R (flip)  12,840  11,249  10,202
#
#       2022          2023                   2023 Population source and notes  \
# 2   33,865        34,502            Dec. 14, 2023 Count Sheet (Grand total)
# 13   8,709         9,005  KS DOC Current populaton totals as of Dec. 13,...
# 15  15,637  None located                                                NaN
# 16   6,001         6,144  MA DOC Weekly Inmate Count as of Dec. 4, 2023 ...
# 20  10,304        10,535  NV DOC Monthly Statistical Abstracts Factsheet...
#
#                                            Source URL Unnamed: 8
# 2   https://corrections.az.gov/sites/default/files...        NaN
# 13   https://www.doc.ks.gov/current_population_totals        NaN
# 15                                                NaN        NaN
# 16  https://www.mass.gov/doc/weekly-inmate-count-1...        NaN
# 20  https://doc.nv.gov/uploadedFiles/docnvgov/cont...        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# If this worked it would pull out Arizona, Kansas, Maryland, Massachusetts, and Nevada.

# %%
df.apply(pd.DataFrame.describe, axis=1)
# Out:
#     count  unique             top  freq
# 2      20      14          Tossup     5
# 13     20      15          Tossup     5
# 15     18      13  Solid D (flip)     4
# 16     20      15  Solid D (flip)     4
# 20     20      14          Tossup     5
# 34     20      14          Tossup     6

# %%
# Define the columns you want to keep
columns_to_keep = ['State', 'Result', '2019', '2020', '2021', '2022', '2023']

# Subset the DataFrame to keep only the desired columns
df_subset = df[columns_to_keep]

# Set 'State' column as the index if needed
df_subset.set_index('State', inplace=True)

# Display the resulting DataFrame
print(df_subset.head())
# Out:
#                                  Result    2019    2020    2021    2022  \
# State
# Arizona           Hobbs\n50.3% D (flip)  42,441  37,794  33,914  33,865
# Kansas                   Kelly\n49.5% D  10,177   8,779   8,521   8,709
# Maryland          Moore\n64.5% D (flip)  18,595  15,623  15,134  15,637
# Massachusetts    Healey\n63.8% D (flip)   8,205   6,762   6,148   6,001
# Nevada         Lombardo\n48.8% R (flip)  12,840  11,249  10,202  10,304
#
#                        2023
# State
# Arizona              34,502
# Kansas                9,005
# Maryland       None located
# Massachusetts         6,144
# Nevada               10,535

# %%
pd.set_option('display.max_columns', None)
print(df_subset)
# Out:
#                                  Result    2019    2020    2021    2022  \
# State
# Arizona           Hobbs\n50.3% D (flip)  42,441  37,794  33,914  33,865
# Kansas                   Kelly\n49.5% D  10,177   8,779   8,521   8,709
# Maryland          Moore\n64.5% D (flip)  18,595  15,623  15,134  15,637
# Massachusetts    Healey\n63.8% D (flip)   8,205   6,762   6,148   6,001
# Nevada         Lombardo\n48.8% R (flip)  12,840  11,249  10,202  10,304
# Wisconsin                Evers\n51.2% D  23,956  20,298  20,202  20,873
#
#                        2023
# State
# Arizona              34,502
# Kansas                9,005
# Maryland       None located
# Massachusetts         6,144
# Nevada               10,535
# Wisconsin            21,923

# %%
print(df_subset.columns)
# Out:
# Index(['Result', '2019', '2020', '2021', '2022', '2023'], dtype='object')

# %%
dfs = df_subset
dfs.head()
# Out:
#                                  Result    2019    2020    2021    2022  \
# State
# Arizona           Hobbs\n50.3% D (flip)  42,441  37,794  33,914  33,865
# Kansas                   Kelly\n49.5% D  10,177   8,779   8,521   8,709
# Maryland          Moore\n64.5% D (flip)  18,595  15,623  15,134  15,637
# Massachusetts    Healey\n63.8% D (flip)   8,205   6,762   6,148   6,001
# Nevada         Lombardo\n48.8% R (flip)  12,840  11,249  10,202  10,304
#
#                        2023
# State
# Arizona              34,502
# Kansas                9,005
# Maryland       None located
# Massachusetts         6,144
# Nevada               10,535
